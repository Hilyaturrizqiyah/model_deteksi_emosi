# %%
import tweepy
import datetime
import pandas as pd

# %%
access_token = "720154828886781952-eEq6tdBcCUAxHLxIsOerSdGr0OVis0M"
access_token_secret = "SArRbc2397FPb1ox6oe6pBi5gD9FlTI2CRYmagZiwzpQX"
api_key = "fgxxAINbeQiX4qLkGNJzbldQm"
api_key_secret = "6PqXhXhOnhv0ZlravGImubw7rzZSSPnPvb2Rrob2g05qK1xXp0"

# %%
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
search_key = "mental"

# %%
c = []
i = []
u = []
t = []

start = datetime.datetime(2020, 3, 2)

for tweet in tweepy.Cursor(api.search_tweets, q=search_key, lang="id", since=start).items():
    c.append(tweet.created_at)
    u.append(tweet.user.name)
    t.append(tweet.text.encode("utf-8"))

tweet = {"waktu": c, "username": u, "text": t}
df = pd.DataFrame(tweet, columns=["waktu", "username", "text"])
# df.drop_duplicates(subset='text', inplace=True)
df.to_csv("crawlingnew.csv", index=False)
df
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
#                        waktu                                    username  \
# 0  2022-08-18 11:14:44+00:00             💜 BTS_ArmyHelpCenter INDONESIAN
# 1  2022-08-18 00:40:52+00:00                        IG: @radiosmartfm959
# 2  2022-08-17 17:06:50+00:00                                       Hippo
# 3  2022-08-17 12:58:49+00:00                105.8 MUJAHIDIN FM PONTIANAK
# 4  2022-08-17 10:08:17+00:00                                        raen
# 5  2022-08-17 09:58:30+00:00                                         zee
# 6  2022-08-17 09:08:34+00:00                             Revolusi Mental
# 7  2022-08-17 06:48:10+00:00                                       zikry
# 8  2022-08-17 06:36:56+00:00                          Anthony Dio Martin
# 9  2022-08-17 00:00:31+00:00                                 ShekhaR_007
# ...

# %%
data1 = pd.read_csv('crawling.csv', on_bad_lines='skip')
data2 = pd.read_csv('crawlingnew.csv', on_bad_lines='skip')

frames = [data1, data2]
result = pd.concat(frames).drop_duplicates().reset_index(drop=True)

# %%
result.to_csv('datatweet.csv', index=False)
